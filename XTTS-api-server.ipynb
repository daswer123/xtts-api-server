# %% [markdown]
# This colab was created by daswer123 for
# https://github.com/daswer123/xtts-api-server
#
# Maybe you wanted to try XTTS but your computer doesn't allow it, then this colab will help you.
#
# If you liked colab and the xtts-api-server project, give it a star

# %% [markdown]
# # INSTALL (takes 2-3 minutes)

# %%
#@markdown #####You can enable gdrive that drag and drop samples directly through your google drive via the `drive/Mydrive` path
mount_gdrive = False #@param{type:"boolean"}

if mount_gdrive:
  from google.colab import drive
  drive.mount('/content/drive')

print("Installing Packages and Dependencies\nPlease wait 2-3 minutes")
# !npm install localtunnel > '/dev/null' 2>&1
# !pip -q install torch==2.1.0 torchvision==0.16.0 torchaudio==2.1.0 --index-url https://download.pytorch.org/whl/cu118 > '/dev/null' 2>&1
# !pip -q install xtts-api-server > '/dev/null' 2>&1
# !pip -q install --force-reinstall numpy==1.26.2 > '/dev/null' 2>&1

print("Downloading a test sample")
# copy exaple sample
# !mkdir speakers > '/dev/null' 2>&1
# !wget -q -O speakers//exapmle.wav https://github.com/daswer123/xtts-api-server/blob/main/xtts_api_server/example.wav

print("Done")

# %% [markdown]
# #Launch

# %%
#@markdown A link and ip address will appear in front of you. You need to follow the link and paste there the given ip address.

#@markdown After that you can copy the link and paste it into the tavern.

#@markdown Also if you are running for the first time you need to confirm the model download by typing "y" in the console
import time

# !nohup npx lt -p 8020 > lt.log 2>&1 &

time.sleep(2)
with open('/content/lt.log', 'r') as testwritefile:
    tunnel_ip = testwritefile.read()
    print(tunnel_ip)
    print("Before you copy the link above click on it and copy that ip:")
    # !curl ipv4.icanhazip.com
    print("\n\n\n\n")
# !python -m xtts_api_server -hs 0.0.0.0
